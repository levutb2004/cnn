# %%
import geopandas as gpd
import pandas as pd
from libpysal.weights import KNN
from esda.moran import Moran
import os

results = []

base_path = r'E:/fake-pomelo/pomelo_input_data'

for i in range(1, 19):
    try:
        shp_path = os.path.join(
            base_path,
            f'VNM_Sample_{i}',
            f'Sample_{i}.shp'
        )
        
        # Load
        gdf = gpd.read_file(shp_path)

        # Dissolve
        dissolved = gdf.dissolve(
            by="GR_SID",
            aggfunc={
                "Total_popu": "sum",
                "is_train": "max"
            }
        ).reset_index()

        # Filter train
        train_gdf = dissolved[dissolved['is_train'] == 1]

        # Spatial weights
        w = KNN.from_dataframe(train_gdf, k=3)

        # Target
        y = train_gdf['Total_popu'].values

        # Moran's I
        mi = Moran(y, w)

        results.append({
            "sample": i,
            "moran_I": mi.I,
            "p_value": mi.p_sim
        })

        print(f"Sample {i}: Moran's I = {mi.I:.4f}")

    except Exception as e:
        print(f"Sample {i} error:", e)

# Save CSV
df_results = pd.DataFrame(results)
df_results.to_csv("E:/fake-pomelo/moransI/moransI_results.csv", index=False)

print("Saved to moransI_results.csv")
# Out:
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 6 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
# Sample 1: Moran's I = 0.2485
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
# Sample 2: Moran's I = 0.2277
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
# Sample 3: Moran's I = 0.4303
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 6 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
# Sample 4: Moran's I = 0.4306
# Sample 5: Moran's I = 0.4621
# Sample 6: Moran's I = 0.4902
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
# Sample 7: Moran's I = 0.5370
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
# Sample 8: Moran's I = 0.6524
# Sample 9: Moran's I = 0.5184
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
# Sample 10: Moran's I = 0.5653
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
# Sample 11: Moran's I = 0.5470
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 4 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
# Sample 12: Moran's I = 0.6084
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
# Sample 13: Moran's I = 0.6075
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 4 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
# Sample 14: Moran's I = 0.6376
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
# Sample 15: Moran's I = 0.7189
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
# Sample 16: Moran's I = 0.7308
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 5 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
# Sample 17: Moran's I = 0.6426
# Sample 18: Moran's I = 0.6757
# Saved to moransI_results.csv
# c:\Users\admin\miniforge3\envs\pomelo\Lib\site-packages\libpysal\weights\distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 5 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)
